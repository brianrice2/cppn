# %% [markdown]
# # Color images
#
# http://blog.otoro.net/2016/03/25/generating-abstract-patterns-with-tensorflow/

# %%
# %run -i sampler.py
sampler = Sampler(z_dim=8, c_dim=3, scale=15, net_size=32)
# Out:
# Using TensorFlow backend.

# %%
z1 = sampler.generate_z()

# %%
img_data = sampler.generate(z1)
sampler.show_image(img_data)

# %%
img_data = sampler.generate(z1)
sampler.show_image(img_data)

# %%
z2 = sampler.generate_z()
sampler.show_image(sampler.generate(z2))

# %%
sampler.save_anim_gif(z1, z2, 'output_color.gif')
# Out:
# processing image 1
# processing image 2
# processing image 3
# processing image 4
# processing image 5
# processing image 6
# processing image 7
# processing image 8
# processing image 9
# processing image 10
# processing image 11
# processing image 12
# writing gif file...
# saved!
